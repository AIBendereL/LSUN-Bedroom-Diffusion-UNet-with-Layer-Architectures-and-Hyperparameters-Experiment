# %% [markdown]
# ### LSUN Bedroom Generator

# %%
import torch
from torch import nn
from torch import optim
from torch.optim import lr_scheduler
from torch.utils.data import default_collate

import numpy as np

from torchvision.io import read_image, ImageReadMode
from torchvision import transforms
from torch.utils.data import DataLoader

import fastcore.all as fc
from fastprogress import progress_bar

from diffusers import AutoencoderKL, UNet2DModel
from diffusers import DDPMScheduler, DDIMScheduler
from diffusers.models.resnet import ResnetBlock2D

from torchmetrics.image.fid import FrechetInceptionDistance
from torchmetrics.image.kid import KernelInceptionDistance

import matplotlib.pyplot as plt
# Out:
# D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
from pathlib import Path
import shutil
from glob import glob
from functools import partial
from itertools import islice

from miniai.init import clean_mem
from miniai.datasets import show_image, show_images
from miniai.learner import to_cpu, Learner, Callback, DeviceCB, ProgressCB, MetricsCB
from miniai.sgd import BatchSchedCB
from miniai.accel import MixedPrecision
from miniai.training import get_dls
from miniai.datasets import DataLoaders
from miniai.fid import ImageEval
from miniai.activations import ActivationStatsMod, set_seed

from miniai_extend.sampling import sampling, latents_to_images
from miniai_extend.evaluation import SamplesEval

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Hyperparameter

# %%
bs = 16

lr = 1e-4
epochs = 40
adam_eps = 1e-5

# %% [markdown]
# ### Device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Config

# %%
figsize_img = (2, 2)
figsize_stats = (10, 2)
figsize_cld = (10, 2)
figsize_cldz = (10, 1)
figsize_dead = (10, 4)

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Data

# %% [markdown]
# #### Data origin

# %%
path_data = Path("data/")
path_data.mkdir(exist_ok= True)
path_bedroom = path_data/"bedroom/"
path_bedroom
# Out:
# Path('data/bedroom')

# %%
url = 'https://s3.amazonaws.com/fast-ai-imageclas/bedroom.tgz'
if not path_bedroom.exists():
    path_zip = fc.urlsave(url, path_data)
    shutil.unpack_archive("data/bedroom.tgz", "data")

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Data subbing

# %%
n_imgs = 10000
path_sub = path_data/f"bedroom_{n_imgs}"
path_sub
# Out:
# Path('data/bedroom_10000')

# %%
# %%time

if not path_sub.exists():
    path_sub.mkdir()

    img_paths = glob(str(path_bedroom/f"**/*.jpg"), recursive= True)
    scr_img_paths = img_paths[:n_imgs]
    dest_img_paths = [path_sub/Path(x).name for x in scr_img_paths]

    [shutil.copy(scr, dest) for scr, dest in zip(scr_img_paths, dest_img_paths)]
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Data class

# %%
def to_tensor(img): return read_image(img, mode= ImageReadMode.RGB)/255

# %%
class ImagesDS():

    def __init__(self, path, spec= ".jpg"):

        self.path = Path(path)
        self.files = glob(str(path/f"**/*{spec}"), recursive= True)

    def __len__(self): return len(self.files)
    def __getitem__(self, i): return to_tensor(self.files[i]), self.files[i]
    def __repr__(self): return f"{len(self.files)} items"

# %%
dts = ImagesDS(path_sub)
dts, dts[0][0].shape, dts[0][1]
# Out:
# (10000 items,
#  torch.Size([3, 256, 341]),
#  'data\\bedroom_10000\\000038527b455eaccd15e623f2e229ecdbceba2b.jpg')

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Original

# %% [raw]
# %%time
#
# imgs_mean = torch.stack([item[0].mean() for item in dts], dim= 0).mean()
# imgs_std = torch.stack([item[0].std() for item in dts], dim= 0).mean()
# imgs_mean, imgs_std

# %%
imgs_mean = 0.5178
imgs_std = 0.2395

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Visualize Image

# %%
def show_image_mod(image, figsize= figsize_img, clamp= True):

    if clamp: image = image.clamp(0, 1)
    show_image(image, figsize= figsize)

def show_images_mod(images, imsize= 1., clamp= True):

    if clamp: images = images.clamp(0, 1)
    show_images(images, imsize= imsize)

# %%
show_image_mod(dts[0][0])

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Transforms

# %%
tfmx = transforms.Compose(
    [
        transforms.Resize((256, 256), antialias= True)])

# %%
class ImagesDSTfm():

    def __init__(self, dts, tfmx= fc.noop, tfmy= fc.noop): fc.store_attr()
    def __len__(self): return len(self.dts)
    def __getitem__(self, i): return self.tfmx(self.dts[i][0]), self.tfmy(self.dts[i][1])
    def __repr__(self): return f"{self.dts} with transforms"

# %%
dts_tfm = ImagesDSTfm(dts, tfmx= tfmx)
dts_tfm, dts_tfm[0][0].shape, dts_tfm[0][1]
# Out:
# (10000 items with transforms,
#  torch.Size([3, 256, 256]),
#  'data\\bedroom_10000\\000038527b455eaccd15e623f2e229ecdbceba2b.jpg')

# %%
show_image_mod(dts_tfm[0][0])

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Transforms

# %% [raw]
# %%time
#
# imgs_tfm_mean = torch.stack([item[0].mean() for item in dts_tfm], dim= 0).mean()
# imgs_tfm_std = torch.stack([item[0].std() for item in dts_tfm], dim= 0).mean()
# imgs_tfm_mean, imgs_tfm_std

# %%
#NoNorm
imgs_tfm_mean = 0.5178
imgs_tfm_std = 0.2371

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### DataLoader

# %%
dls = DataLoader(dts_tfm, batch_size= bs, shuffle= True)
xb, yb = next(iter(dls))
xb.shape
# Out:
# torch.Size([16, 3, 256, 256])

# %%
show_images_mod(xb[:9])

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### VAE

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").requires_grad_(False).to(device)

# %% [markdown]
# #### Latents

# %%
path_ltt = path_data/f"bedroom_{n_imgs}_latents_nonorm/"
path_ltt
# Out:
# Path('data/bedroom_10000_latents_nonorm')

# %%
if not path_ltt.exists():
    path_ltt.mkdir()

    for imgs, paths in progress_bar(dls):

        ltts = vae.encode(imgs.to(device))
        ltts_m_np = to_cpu(ltts.latent_dist.mean).numpy()

        [np.save(path_ltt/Path(p).with_suffix(".npy").name, ltt)
         for p, ltt in zip(paths, ltts_m_np)]

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Data Splitting

# %%
path_trn = Path(f"{path_ltt}_train/")
path_val = Path(f"{path_ltt}_valid/")
path_trn, path_val
# Out:
# (Path('data/bedroom_10000_latents_nonorm_train'),
#  Path('data/bedroom_10000_latents_nonorm_valid'))

# %%
split_portion = 0.1
n_trn = int(n_imgs * (1-split_portion))
n_trn
# Out:
# 9000

# %%
# %%time

if not path_trn.exists() or not path_val.exists():
    path_trn.mkdir()
    path_val.mkdir()

    ltt_files = glob(f"{path_ltt}/**/*.npy", recursive= True)
    ltt_files_trn = ltt_files[:n_trn]
    ltt_files_val = ltt_files[n_trn:]

    [shutil.copy(p, path_trn/Path(p).name) for p in ltt_files_trn]
    [shutil.copy(p, path_val/Path(p).name) for p in ltt_files_val]
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Latents Dataset

# %% [markdown]
# #### Data Class

# %%
class NumpyDS(ImagesDS):

    def __getitem__(self, i): return torch.from_numpy(np.load(self.files[i])), self.files[i]

# %%
dts_trn = NumpyDS(path_trn, spec= ".npy")
dts_trn, dts_trn[0][0].shape, dts_trn[0][1]
# Out:
# (9000 items,
#  torch.Size([4, 32, 32]),
#  'data\\bedroom_10000_latents_nonorm_train\\000038527b455eaccd15e623f2e229ecdbceba2b.npy')

# %%
dts_val = NumpyDS(path_val, spec= ".npy")
dts_val, dts_val[0][0].shape, dts_val[0][1]
# Out:
# (1000 items,
#  torch.Size([4, 32, 32]),
#  'data\\bedroom_10000_latents_nonorm_valid\\073bf236c811160148e09bb29b1409f649add958.npy')

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Latents

# %% [raw]
# %%time
#
# ltts_mean = torch.stack([item[0].mean() for item in dts_trn], dim= 0).mean()
# ltts_std = torch.stack([item[0].std() for item in dts_trn], dim= 0).mean()
# ltts_mean, ltts_std

# %%
#NoNorm
ltts_mean = 1.7197
ltts_std = 4.8114

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Dataloader

# %% [raw]
# set_seed(42)

# %%
def noisify_mod(b, sched):

    device = b.device
    n = len(b)

    t = torch.randint(high= sched.config.num_train_timesteps, size= (n,)).to(device)
    noise = torch.randn(b.shape).to(device)

    noise_image = sched.add_noise(b, noise, t)

    return (noise_image, t), noise

# %%
sched = DDIMScheduler(beta_end= 0.01)
noisify = partial(noisify_mod, sched= sched)

# %%
def collate_ddpm(b): return noisify(default_collate(b)[0]*0.18215)

# %%
dls = DataLoaders(*get_dls(dts_trn, dts_val, bs= bs, collate_fn= collate_ddpm))

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Noisy Latents

# %% [raw]
# %%time
#
# n_ltts_mean = torch.stack([item[0][0].mean() for item in dls.train], dim= 0).mean()
# n_ltts_std = torch.stack([item[0][0].std() for item in dls.train], dim= 0).mean()
# n_ltts_mean, n_ltts_std

# %%
n_ltts_mean_100k = 0.1696
n_ltts_std_100k = 0.9615

# %%
n_ltts_mean = 0.1861
n_ltts_std = 0.9941

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Training

# %%
class TrainLearner(Learner):

    def predict(self): self.preds = self.model(*self.batch[0]).sample
    def get_loss(self): self.loss = self.loss_func(self.preds, self.batch[1])
    def backward(self): self.loss.backward()
    def step(self): self.opt.step()
    def zero_grad(self): self.opt.zero_grad()

# %% [markdown]
# #### ----------

# %% [markdown]
# #### ResnetBlock: LoRA -> Conv | Linear

# %%
def lora_to_conv(m, spec):

    lora = getattr(m, spec)
    channels = lora.in_channels, lora.out_channels
    ks, s, p = lora.kernel_size, lora.stride, lora.padding

    conv = nn.Conv2d(*channels, kernel_size= ks, stride= s, padding= p)
    setattr(m, spec, conv)

def lora_to_linear(m, spec):

    lora = getattr(m, spec)
    features = lora.in_features, lora.out_features

    linear = nn.Linear(*features)
    setattr(m, spec, linear)

def unet_conv(model):

    for n, m in model.named_modules():

        if m.__class__.__name__ == "ResnetBlock2D":

            nm_dict = dict(m.named_modules())

            names = nm_dict.keys()
            [delattr(m, name) for name in reversed(names) if name]

            m.norm1 = nm_dict["norm1"]
            m.nonlinearity0 = nm_dict["nonlinearity"]
            m.conv1 = nm_dict["conv1"]
            m.time_emb_proj = nm_dict["time_emb_proj"]

            m.norm2 = nm_dict["norm2"]
            m.dropout = nm_dict["dropout"]
            m.nonlinearity = nm_dict["nonlinearity"]
            m.conv2 = nm_dict["conv2"]
            if "conv_shortcut" in nm_dict: m.conv_shortcut = nm_dict["conv_shortcut"]
            
            lora_to_conv(m, spec= "conv1")
            lora_to_linear(m, spec= "time_emb_proj")
            lora_to_conv(m, spec= "conv2")
            if "conv_shortcut" in nm_dict: lora_to_conv(m, spec= "conv_shortcut")

        if m.__class__.__name__ == "Downsample2D" or m.__class__.__name__ == "Upsample2D":
            
            lora_to_conv(m, spec= "conv")

# %% [markdown]
# #### ----------

# %% [markdown]
# #### ResnetBlock: GroupNorm -> BatchNorm | conv_norm_out: GroupNorm -> BatchNorm

# %%
def unet_batchnorm(model):

    bnorm_gen = partial(nn.BatchNorm2d, eps= 1e-05, momentum= 0.1, affine= True, track_running_stats= True)

    for n, m in model.named_modules():

        if m.__class__.__name__ == "ResnetBlock2D":

            norm1_fts = m.norm1.num_channels
            norm2_fts = m.norm2.num_channels

            m.norm1 = bnorm_gen(num_features= norm1_fts)
            m.norm2 = bnorm_gen(num_features= norm2_fts)

        if n.endswith("conv_norm_out"):
    
            norm_channels = m.num_channels
            model.conv_norm_out = bnorm_gen(num_features= norm_channels)

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Init Unet

# %%
def init_unet(model, spec= "conv2"):

    gain = nn.init.calculate_gain("relu")
    for n, m in model.named_modules():

        if n.endswith(spec): nn.init.xavier_normal_(m.weight, gain= gain)

# %%
model = UNet2DModel(in_channels= 4, out_channels= 4, block_out_channels= (32, 32, 64, 64, 128, 128),
                    down_block_types = (
                        "DownBlock2D",
                        "AttnDownBlock2D",
                        "AttnDownBlock2D",
                        "AttnDownBlock2D",
                        "AttnDownBlock2D",
                        "AttnDownBlock2D"),
                    up_block_types = (
                        "AttnUpBlock2D",
                        "AttnUpBlock2D",
                        "AttnUpBlock2D",
                        "AttnUpBlock2D",
                        "AttnUpBlock2D",
                        "UpBlock2D"))

unet_conv(model)
unet_batchnorm(model)
init_unet(model, spec= "conv2")

# %% [raw]
# "DownBlock2D", "UpBlock2D", "AttnDownBlock2D", "AttnUpBlock2D"

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Train

# %%
loss_func = nn.MSELoss()
opt_func = partial(optim.AdamW, eps= adam_eps)

total_steps = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr= lr, total_steps= total_steps)

act_stats = ActivationStatsMod(fc.risinstance(ResnetBlock2D))

cbs = [DeviceCB(), ProgressCB(plot= True), MetricsCB(), BatchSchedCB(sched), MixedPrecision(), act_stats]
learn = TrainLearner(model, dls, loss_func= loss_func, lr= lr, cbs= cbs, opt_func= opt_func)

# %%
# %%time

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.950</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.803</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.681</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.573</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.476</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.392</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.361</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.332</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.314</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.277</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.287</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.269</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.262</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.251</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.254</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.249</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.248</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.240</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.226</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.242</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.247</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.231</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.255</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.235</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.222</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.233</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.225</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.230</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.229</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.231</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.220</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.223</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.230</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.224</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.220</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.227</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.226</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.227</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.226</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.223</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.253</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.223</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.226</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.226</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>25</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>25</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>26</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>26</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.224</td>
#       <td>27</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.232</td>
#       <td>27</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>28</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>28</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.220</td>
#       <td>29</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>29</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.220</td>
#       <td>30</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.225</td>
#       <td>30</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.218</td>
#       <td>31</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.201</td>
#       <td>31</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.222</td>
#       <td>32</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.202</td>
#       <td>32</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>33</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.212</td>
#       <td>33</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>34</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.207</td>
#       <td>34</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>35</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>35</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>36</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.224</td>
#       <td>36</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>37</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.227</td>
#       <td>37</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.226</td>
#       <td>38</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.224</td>
#       <td>38</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>39</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.228</td>
#       <td>39</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: total: 13h 57min 16s
# Wall time: 1h 59min 11s

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Activation Stats

# %%
def show_act_stats(act_stats, n_chart= 10):

    act_stats.plot_stats(figsize= figsize_stats, n_chart= n_chart)
    # act_stats.color_dim(figsize= figsize_cld, n_chart= n_chart)
    # act_stats.color_dim_zoom(figsize= figsize_cldz, n_chart= n_chart)
    act_stats.dead_chart(figsize= figsize_dead, n_chart= n_chart)

# %%
show_act_stats(act_stats, n_chart= 20)

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Saving Model

# %% [raw]
# path_model = Path("models/")
# name_model = "lsun_diffusion_unet_(32_32_64_64_128_128)_(DAAAAA)_InitXavierNormRelu_BN_Bs16_Lr1e-4_10k_40e.pt"
# torch.save(learn.model.state_dict(), path_model/name_model)

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Sampling

# %% [markdown]
# #### DDIM

# %%
sched = DDIMScheduler(beta_end= 0.01)
steps = 100
size = (16, 4, 32, 32)
eta = 1.

samples = sampling(sched, learn.model, steps= steps, size= size, eta= eta)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:03&lt;00:00]
#     </div>

# %%
# %%time

s = samples[-1]/0.18215
with torch.no_grad(): imgs_ddim = latents_to_images(vae, s, clamp= True, device= device)
imgs_ddim.shape
# Out:
# CPU times: total: 7.73 s
# Wall time: 6.49 s
# torch.Size([16, 3, 256, 256])

# %%
show_images_mod(imgs_ddim[:16])

# %%
clean_mem()

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Train more

# %% [markdown]
# #### Train

# %%
epochs = 20

# %%
loss_func = nn.MSELoss()
opt_func = partial(optim.AdamW, eps= adam_eps)

total_steps = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr= lr, total_steps= total_steps)

act_stats = ActivationStatsMod(fc.risinstance(ResnetBlock2D))

cbs = [DeviceCB(), ProgressCB(plot= True), MetricsCB(), BatchSchedCB(sched), MixedPrecision(), act_stats]
learn = TrainLearner(model, dls, loss_func= loss_func, lr= lr, cbs= cbs, opt_func= opt_func)

# %%
# %%time

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.218</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.237</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.234</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.228</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.212</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.237</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.235</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.218</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.218</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.212</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.220</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.218</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.210</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.227</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.210</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.199</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: total: 6h 51min 14s
# Wall time: 59min 40s

# %% [markdown]
# #### Act

# %%
show_act_stats(act_stats, n_chart= 20)

# %% [markdown]
# #### Save

# %%
path_model = Path("models/")
name_model = "lsun_diffusion_unet_(32_32_64_64_128_128)_(DAAAAA)_InitXavierNormRelu_BN_Bs16_Lr1e-4_10k_40e+20e.pt"
torch.save(learn.model.state_dict(), path_model/name_model)

# %% [markdown]
# #### Sample

# %%
sched = DDIMScheduler(beta_end= 0.01)
steps = 100
size = (16, 4, 32, 32)
eta = 1.

samples = sampling(sched, learn.model, steps= steps, size= size, eta= eta)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:03&lt;00:00]
#     </div>

# %%
# %%time

s = samples[-1]/0.18215
with torch.no_grad(): imgs_ddim = latents_to_images(vae, s, clamp= True, device= device)
imgs_ddim.shape
# Out:
# CPU times: total: 7.61 s
# Wall time: 6.4 s
# torch.Size([16, 3, 256, 256])

# %%
show_images_mod(imgs_ddim[:16])

# %%
clean_mem()

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Train even more

# %% [markdown]
# #### Train

# %%
epochs = 40

# %%
loss_func = nn.MSELoss()
opt_func = partial(optim.AdamW, eps= adam_eps)

total_steps = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr= lr, total_steps= total_steps)

act_stats = ActivationStatsMod(fc.risinstance(ResnetBlock2D))

cbs = [DeviceCB(), ProgressCB(plot= True), MetricsCB(), BatchSchedCB(sched), MixedPrecision(), act_stats]
learn = TrainLearner(model, dls, loss_func= loss_func, lr= lr, cbs= cbs, opt_func= opt_func)

# %%
# %%time

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.211</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.219</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.220</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.223</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.205</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.229</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.244</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.240</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.253</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.232</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.207</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.217</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.212</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.206</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.212</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.201</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.232</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.203</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.210</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.198</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.212</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.233</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.244</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.193</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.201</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.210</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.211</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>25</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.232</td>
#       <td>25</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>26</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>26</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>27</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.221</td>
#       <td>27</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.207</td>
#       <td>28</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.222</td>
#       <td>28</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.207</td>
#       <td>29</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.222</td>
#       <td>29</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.214</td>
#       <td>30</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.222</td>
#       <td>30</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>31</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.213</td>
#       <td>31</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.206</td>
#       <td>32</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>32</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>33</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.208</td>
#       <td>33</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.209</td>
#       <td>34</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.216</td>
#       <td>34</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.210</td>
#       <td>35</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.201</td>
#       <td>35</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.207</td>
#       <td>36</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.251</td>
#       <td>36</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.207</td>
#       <td>37</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.229</td>
#       <td>37</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.206</td>
#       <td>38</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.215</td>
#       <td>38</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.210</td>
#       <td>39</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>39</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: total: 14h 24min 5s
# Wall time: 2h 21min 27s

# %% [markdown]
# #### Act

# %%
show_act_stats(act_stats, n_chart= 20)

# %% [markdown]
# #### Save

# %%
path_model = Path("models/")
name_model = "lsun_diffusion_unet_(32_32_64_64_128_128)_(DAAAAA)_InitXavierNormRelu_BN_Bs16_Lr1e-4_10k_40e+20e+40e.pt"
torch.save(learn.model.state_dict(), path_model/name_model)

# %% [markdown]
# #### Sample

# %%
sched = DDIMScheduler(beta_end= 0.01)
steps = 100
size = (16, 4, 32, 32)
eta = 1.

samples = sampling(sched, learn.model, steps= steps, size= size, eta= eta)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:03&lt;00:00]
#     </div>

# %%
# %%time

s = samples[-1]/0.18215
with torch.no_grad(): imgs_ddim = latents_to_images(vae, s, clamp= True, device= device)
imgs_ddim.shape
# Out:
# CPU times: total: 7.91 s
# Wall time: 6.49 s
# torch.Size([16, 3, 256, 256])

# %%
show_images_mod(imgs_ddim[:16])

# %%
clean_mem()

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Evaluation

# %% [raw]
# dls_eval = DataLoader(dts_tfm, batch_size= bs, shuffle= False)
#
# imgs_eval, _ = next(iter(dls_eval))
# imgs_eval.shape, imgs_eval.dtype

# %% [raw]
# percent_eval = 0.05
#
# samples_eval = SamplesEval(dls_eval, percent= percent_eval, device= device)
# samples_eval.init_kid(feature= 2048, subset_size= 32, reset_real_features= False)

# %% [raw]
# mult = 1e4

# %% [raw]
# #Origin
# kid_ori = samples_eval.kid_eval(imgs_eval)
# kid_ori[0] * mult, kid_ori[1]

# %% [raw]
# #Sample
# kid_samples = samples_eval.kid_eval(imgs_ddim)
# kid_samples[0] * mult, kid_samples[1]

# %% [markdown]
# ### ----------------------------------------
