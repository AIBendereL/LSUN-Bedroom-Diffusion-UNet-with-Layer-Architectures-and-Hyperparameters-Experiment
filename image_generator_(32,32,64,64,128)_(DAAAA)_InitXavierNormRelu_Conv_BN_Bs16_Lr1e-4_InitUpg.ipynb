# %% [markdown]
# ### LSUN Bedroom Generator

# %%
import torch
from torch import nn
from torch import optim
from torch.optim import lr_scheduler
from torch.utils.data import default_collate

import numpy as np

from torchvision.io import read_image, ImageReadMode
from torchvision import transforms
from torch.utils.data import DataLoader

import fastcore.all as fc
from fastprogress import progress_bar

from diffusers import AutoencoderKL, UNet2DModel
from diffusers import DDPMScheduler, DDIMScheduler
from diffusers.models.resnet import ResnetBlock2D

from torchmetrics.image.fid import FrechetInceptionDistance
from torchmetrics.image.kid import KernelInceptionDistance

import matplotlib.pyplot as plt

# %%
from pathlib import Path
import shutil
from glob import glob
from functools import partial
from itertools import islice

from miniai.init import clean_mem
from miniai.datasets import show_image, show_images
from miniai.learner import to_cpu, Learner, Callback, DeviceCB, ProgressCB, MetricsCB
from miniai.sgd import BatchSchedCB
from miniai.accel import MixedPrecision
from miniai.training import get_dls
from miniai.datasets import DataLoaders
from miniai.fid import ImageEval
from miniai.activations import ActivationStatsMod, set_seed

from miniai_extend.sampling import sampling, latents_to_images
from miniai_extend.evaluation import SamplesEval

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Hyperparameter

# %%
bs = 16

lr = 1e-4
epochs = 5
adam_eps = 1e-5

# %% [markdown]
# ### Device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Config

# %%
figsize_img = (2, 2)
figsize_stats = (10, 2)
figsize_cld = (10, 2)
figsize_cldz = (10, 1)
figsize_dead = (10, 4)

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Data

# %% [markdown]
# #### Data origin

# %%
path_data = Path("data/")
path_data.mkdir(exist_ok= True)
path_bedroom = path_data/"bedroom/"
path_bedroom
# Out:
# Path('data/bedroom')

# %%
url = 'https://s3.amazonaws.com/fast-ai-imageclas/bedroom.tgz'
if not path_bedroom.exists():
    path_zip = fc.urlsave(url, path_data)
    shutil.unpack_archive("data/bedroom.tgz", "data")

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Data subbing

# %%
n_imgs = 10000
path_sub = path_data/f"bedroom_{n_imgs}"
path_sub
# Out:
# Path('data/bedroom_10000')

# %%
# %%time

if not path_sub.exists():
    path_sub.mkdir()

    img_paths = glob(str(path_bedroom/f"**/*.jpg"), recursive= True)
    scr_img_paths = img_paths[:n_imgs]
    dest_img_paths = [path_sub/Path(x).name for x in scr_img_paths]

    [shutil.copy(scr, dest) for scr, dest in zip(scr_img_paths, dest_img_paths)]
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Data class

# %%
def to_tensor(img): return read_image(img, mode= ImageReadMode.RGB)/255

# %%
class ImagesDS():

    def __init__(self, path, spec= ".jpg"):

        self.path = Path(path)
        self.files = glob(str(path/f"**/*{spec}"), recursive= True)

    def __len__(self): return len(self.files)
    def __getitem__(self, i): return to_tensor(self.files[i]), self.files[i]
    def __repr__(self): return f"{len(self.files)} items"

# %%
dts = ImagesDS(path_sub)
dts, dts[0][0].shape, dts[0][1]
# Out:
# (10000 items,
#  torch.Size([3, 256, 341]),
#  'data\\bedroom_10000\\000038527b455eaccd15e623f2e229ecdbceba2b.jpg')

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Original

# %% [raw]
# %%time
#
# imgs_mean = torch.stack([item[0].mean() for item in dts], dim= 0).mean()
# imgs_std = torch.stack([item[0].std() for item in dts], dim= 0).mean()
# imgs_mean, imgs_std

# %%
imgs_mean = 0.5178
imgs_std = 0.2395

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Visualize Image

# %%
def show_image_mod(image, figsize= figsize_img, clamp= True):

    if clamp: image = image.clamp(0, 1)
    show_image(image, figsize= figsize)

def show_images_mod(images, imsize= 1., clamp= True):

    if clamp: images = images.clamp(0, 1)
    show_images(images, imsize= imsize)

# %%
show_image_mod(dts[0][0])

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Transforms

# %%
tfmx = transforms.Compose(
    [
        transforms.Resize((256, 256), antialias= True)])

# %%
class ImagesDSTfm():

    def __init__(self, dts, tfmx= fc.noop, tfmy= fc.noop): fc.store_attr()
    def __len__(self): return len(self.dts)
    def __getitem__(self, i): return self.tfmx(self.dts[i][0]), self.tfmy(self.dts[i][1])
    def __repr__(self): return f"{self.dts} with transforms"

# %%
dts_tfm = ImagesDSTfm(dts, tfmx= tfmx)
dts_tfm, dts_tfm[0][0].shape, dts_tfm[0][1]
# Out:
# (10000 items with transforms,
#  torch.Size([3, 256, 256]),
#  'data\\bedroom_10000\\000038527b455eaccd15e623f2e229ecdbceba2b.jpg')

# %%
show_image_mod(dts_tfm[0][0])

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Transforms

# %% [raw]
# %%time
#
# imgs_tfm_mean = torch.stack([item[0].mean() for item in dts_tfm], dim= 0).mean()
# imgs_tfm_std = torch.stack([item[0].std() for item in dts_tfm], dim= 0).mean()
# imgs_tfm_mean, imgs_tfm_std

# %%
#NoNorm
imgs_tfm_mean = 0.5178
imgs_tfm_std = 0.2371

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### DataLoader

# %%
dls = DataLoader(dts_tfm, batch_size= bs, shuffle= True)
xb, yb = next(iter(dls))
xb.shape
# Out:
# torch.Size([16, 3, 256, 256])

# %%
show_images_mod(xb[:9])

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### VAE

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").requires_grad_(False).to(device)

# %% [markdown]
# #### Latents

# %%
path_ltt = path_data/f"bedroom_{n_imgs}_latents_nonorm/"
path_ltt
# Out:
# Path('data/bedroom_10000_latents_nonorm')

# %%
if not path_ltt.exists():
    path_ltt.mkdir()

    for imgs, paths in progress_bar(dls):

        ltts = vae.encode(imgs.to(device))
        ltts_m_np = to_cpu(ltts.latent_dist.mean).numpy()

        [np.save(path_ltt/Path(p).with_suffix(".npy").name, ltt)
         for p, ltt in zip(paths, ltts_m_np)]

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Data Splitting

# %%
path_trn = Path(f"{path_ltt}_train/")
path_val = Path(f"{path_ltt}_valid/")
path_trn, path_val
# Out:
# (Path('data/bedroom_10000_latents_nonorm_train'),
#  Path('data/bedroom_10000_latents_nonorm_valid'))

# %%
split_portion = 0.1
n_trn = int(n_imgs * (1-split_portion))
n_trn
# Out:
# 9000

# %%
# %%time

if not path_trn.exists() or not path_val.exists():
    path_trn.mkdir()
    path_val.mkdir()

    ltt_files = glob(f"{path_ltt}/**/*.npy", recursive= True)
    ltt_files_trn = ltt_files[:n_trn]
    ltt_files_val = ltt_files[n_trn:]

    [shutil.copy(p, path_trn/Path(p).name) for p in ltt_files_trn]
    [shutil.copy(p, path_val/Path(p).name) for p in ltt_files_val]
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Latents Dataset

# %% [markdown]
# #### Data Class

# %%
class NumpyDS(ImagesDS):

    def __getitem__(self, i): return torch.from_numpy(np.load(self.files[i])), self.files[i]

# %%
dts_trn = NumpyDS(path_trn, spec= ".npy")
dts_trn, dts_trn[0][0].shape, dts_trn[0][1]
# Out:
# (9000 items,
#  torch.Size([4, 32, 32]),
#  'data\\bedroom_10000_latents_nonorm_train\\000038527b455eaccd15e623f2e229ecdbceba2b.npy')

# %%
dts_val = NumpyDS(path_val, spec= ".npy")
dts_val, dts_val[0][0].shape, dts_val[0][1]
# Out:
# (1000 items,
#  torch.Size([4, 32, 32]),
#  'data\\bedroom_10000_latents_nonorm_valid\\073bf236c811160148e09bb29b1409f649add958.npy')

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Latents

# %% [raw]
# %%time
#
# ltts_mean = torch.stack([item[0].mean() for item in dts_trn], dim= 0).mean()
# ltts_std = torch.stack([item[0].std() for item in dts_trn], dim= 0).mean()
# ltts_mean, ltts_std

# %%
#NoNorm
ltts_mean = 1.7197
ltts_std = 4.8114

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Dataloader

# %%
set_seed(42)

# %%
def noisify_mod(b, sched):

    device = b.device
    n = len(b)

    t = torch.randint(high= sched.config.num_train_timesteps, size= (n,)).to(device)
    noise = torch.randn(b.shape).to(device)

    noise_image = sched.add_noise(b, noise, t)

    return (noise_image, t), noise

# %%
sched = DDIMScheduler(beta_end= 0.01)
noisify = partial(noisify_mod, sched= sched)

# %%
def collate_ddpm(b): return noisify(default_collate(b)[0]*0.18215)

# %%
dls = DataLoaders(*get_dls(dts_trn, dts_val, bs= bs, collate_fn= collate_ddpm))

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Mean | Std | Noisy Latents

# %% [raw]
# %%time
#
# n_ltts_mean = torch.stack([item[0][0].mean() for item in dls.train], dim= 0).mean()
# n_ltts_std = torch.stack([item[0][0].std() for item in dls.train], dim= 0).mean()
# n_ltts_mean, n_ltts_std

# %%
n_ltts_mean_100k = 0.1696
n_ltts_std_100k = 0.9615

# %%
n_ltts_mean = 0.1861
n_ltts_std = 0.9941

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Training

# %%
class TrainLearner(Learner):

    def predict(self): self.preds = self.model(*self.batch[0]).sample
    def get_loss(self): self.loss = self.loss_func(self.preds, self.batch[1])
    def backward(self): self.loss.backward()
    def step(self): self.opt.step()
    def zero_grad(self): self.opt.zero_grad()

# %% [markdown]
# #### ----------

# %% [markdown]
# #### ResnetBlock: LoRA -> Conv | Linear

# %%
def lora_to_conv(m, spec):

    lora = getattr(m, spec)
    channels = lora.in_channels, lora.out_channels
    ks, s, p = lora.kernel_size, lora.stride, lora.padding

    conv = nn.Conv2d(*channels, kernel_size= ks, stride= s, padding= p)
    setattr(m, spec, conv)

def lora_to_linear(m, spec):

    lora = getattr(m, spec)
    features = lora.in_features, lora.out_features

    linear = nn.Linear(*features)
    setattr(m, spec, linear)

def unet_conv(model):

    for n, m in model.named_modules():

        if m.__class__.__name__ == "ResnetBlock2D":

            nm_dict = dict(m.named_modules())

            names = nm_dict.keys()
            [delattr(m, name) for name in reversed(names) if name]

            m.norm1 = nm_dict["norm1"]
            m.nonlinearity0 = nm_dict["nonlinearity"]
            m.conv1 = nm_dict["conv1"]
            m.time_emb_proj = nm_dict["time_emb_proj"]

            m.norm2 = nm_dict["norm2"]
            m.dropout = nm_dict["dropout"]
            m.nonlinearity = nm_dict["nonlinearity"]
            m.conv2 = nm_dict["conv2"]
            if "conv_shortcut" in nm_dict: m.conv_shortcut = nm_dict["conv_shortcut"]
            
            lora_to_conv(m, spec= "conv1")
            lora_to_linear(m, spec= "time_emb_proj")
            lora_to_conv(m, spec= "conv2")
            if "conv_shortcut" in nm_dict: lora_to_conv(m, spec= "conv_shortcut")

        if m.__class__.__name__ == "Downsample2D" or m.__class__.__name__ == "Upsample2D":
            
            lora_to_conv(m, spec= "conv")

# %% [markdown]
# #### ----------

# %% [markdown]
# #### ResnetBlock: GroupNorm -> BatchNorm | conv_norm_out: GroupNorm -> BatchNorm

# %%
def unet_batchnorm(model):

    bnorm_gen = partial(nn.BatchNorm2d, eps= 1e-05, momentum= 0.1, affine= True, track_running_stats= True)

    for n, m in model.named_modules():

        if m.__class__.__name__ == "ResnetBlock2D":

            norm1_fts = m.norm1.num_channels
            norm2_fts = m.norm2.num_channels

            m.norm1 = bnorm_gen(num_features= norm1_fts)
            m.norm2 = bnorm_gen(num_features= norm2_fts)

        if n.endswith("conv_norm_out"):
    
            norm_channels = m.num_channels
            model.conv_norm_out = bnorm_gen(num_features= norm_channels)

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Init Unet

# %%
def init_unet(model, spec= "conv2"):

    gain = nn.init.calculate_gain("relu")
    for n, m in model.named_modules():

        if n.endswith(spec): nn.init.xavier_normal_(m.weight, gain= gain)

def init_zero_unet(model, spec= "conv2"):

    for n, m in model.named_modules():

        if n.endswith(spec): nn.init.zeros_(m.weight)

# %%
model = UNet2DModel(in_channels= 4, out_channels= 4, block_out_channels= (64, 128, 256, 512),
                    down_block_types = (
                        "DownBlock2D",
                        "AttnDownBlock2D",
                        "AttnDownBlock2D",
                        "AttnDownBlock2D"),
                    up_block_types = (
                        "AttnUpBlock2D",
                        "AttnUpBlock2D",
                        "AttnUpBlock2D",
                        "UpBlock2D"))

unet_conv(model)
unet_batchnorm(model)

init_unet(model, spec= "conv1")
init_unet(model, spec= "conv2")
# init_zero_unet(model, spec= "conv2")

# %% [raw]
# "DownBlock2D", "UpBlock2D", "AttnDownBlock2D", "AttnUpBlock2D"

# %% [markdown]
# #### ----------

# %% [markdown]
# #### Train

# %%
loss_func = nn.MSELoss()
opt_func = partial(optim.AdamW, eps= adam_eps)

total_steps = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr= lr, total_steps= total_steps)

act_stats = ActivationStatsMod(fc.risinstance(ResnetBlock2D))

cbs = [DeviceCB(), ProgressCB(plot= True), MetricsCB(), BatchSchedCB(sched), MixedPrecision(), act_stats]
learn = TrainLearner(model, dls, loss_func= loss_func, lr= lr, cbs= cbs, opt_func= opt_func)

# %%
# %%time

learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 04:34&lt;06:51]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.698</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.344</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.284</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.306</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='206' class='' max='563' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.59% [206/563 01:03&lt;01:50 0.197]
#     </div>
# Exception ignored in: <function TransformNode.set_children.<locals>.<lambda> at 0x000001F03E559430>
# Traceback (most recent call last):
#   File "D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\transforms.py", line 209, in <lambda>
#     self, lambda _, pop=child._parents.pop, k=id(self): pop(k))
# KeyboardInterrupt:
# -------------------------------------------------------------------------
# KeyboardInterrupt                       Traceback (most recent call last)
# File <timed eval>:1
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:178, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     176     if lr is None: lr = self.lr
#     177     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 178     self._fit(train, valid)
#     179 finally:
#     180     for cb in cbs: self.cbs.remove(cb)
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:166, in Learner._fit(self, train, valid)
#     163 @with_cbs('fit')
#     164 def _fit(self, train, valid):
#     165     for self.epoch in self.epochs:
# --> 166         if train: self.one_epoch(True)
#     167         if valid: torch.no_grad()(self.one_epoch)(False)
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:161, in Learner.one_epoch(self, training)
#     159 self.model.train(training)
#     160 self.dl = self.dls.train if training else self.dls.valid
# --> 161 self._one_epoch()
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:156, in Learner._one_epoch(self)
#     154 @with_cbs('epoch')
#     155 def _one_epoch(self):
# --> 156     for self.iter,self.batch in enumerate(self.dl): self._one_batch()
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:130, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     128     o.callback(f'before_{self.nm}')
#     129     f(o, *args, **kwargs)
# --> 130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#     132 finally: o.callback(f'cleanup_{self.nm}')
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:186, in Learner.callback(self, method_nm)
# --> 186 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File D:\AI_Bender\Fast_ai\Practical_DL_adv\image_generator\miniai\learner.py:114, in ProgressCB.after_batch(self, learn)
#     112 if self.plot and hasattr(learn, 'metrics') and learn.training:
#     113     self.losses.append(learn.loss.item())
# --> 114     if self.val_losses: self.mbar.update_graph([[fc.L.range(self.losses), self.losses],[fc.L.range(learn.epoch).map(lambda x: (x+1)*len(learn.dls.train)), self.val_losses]])
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\fastprogress\fastprogress.py:208, in NBMasterBar.update_graph(self, graphs, x_bounds, y_bounds, figsize)
#     206 if x_bounds is not None: self.graph_ax.set_xlim(*x_bounds)
#     207 if y_bounds is not None: self.graph_ax.set_ylim(*y_bounds)
# --> 208 self.graph_out.update(self.graph_ax.figure)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\display_functions.py:374, in DisplayHandle.update(self, obj, **kwargs)
#     364 def update(self, obj, **kwargs):
#     365     """Update existing displays with my id
#     366
#     367     Parameters
#    (...)
#     372         additional keyword arguments passed to update_display
#     373     """
# --> 374     update_display(obj, display_id=self.display_id, **kwargs)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\display_functions.py:326, in update_display(obj, display_id, **kwargs)
#     312 """Update an existing display by id
#     313
#     314 Parameters
#    (...)
#     323 :func:`display`
#     324 """
#     325 kwargs['update'] = True
# --> 326 display(obj, display_id=display_id, **kwargs)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\figure.py:3140, in Figure.draw(self, renderer)
#    3137         # ValueError can occur when resizing a window.
#    3139 self.patch.draw(renderer)
# -> 3140 mimage._draw_list_compositing_images(
#    3141     renderer, self, artists, self.suppressComposite)
#    3143 for sfig in self.subfigs:
#    3144     sfig.draw(renderer)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\axis.py:1376, in Axis.draw(self, renderer, *args, **kwargs)
#    1373     return
#    1374 renderer.open_group(__name__, gid=self.get_gid())
# -> 1376 ticks_to_draw = self._update_ticks()
#    1377 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1379 for tick in ticks_to_draw:
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\axis.py:1270, in Axis._update_ticks(self)
#    1268     tick.set_label1(label)
#    1269     tick.set_label2(label)
# -> 1270 minor_locs = self.get_minorticklocs()
#    1271 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1272 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\axis.py:1491, in Axis.get_minorticklocs(self)
#    1489 minor_locs = np.asarray(self.minor.locator())
#    1490 if self.remove_overlapping_locs:
# -> 1491     major_locs = self.major.locator()
#    1492     transform = self._scale.get_transform()
#    1493     tr_minor_locs = transform.transform(minor_locs)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\ticker.py:2136, in MaxNLocator.__call__(self)
#    2134 def __call__(self):
#    2135     vmin, vmax = self.axis.get_view_interval()
# -> 2136     return self.tick_values(vmin, vmax)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\ticker.py:2144, in MaxNLocator.tick_values(self, vmin, vmax)
#    2141     vmin = -vmax
#    2142 vmin, vmax = mtransforms.nonsingular(
#    2143     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144 locs = self._raw_ticks(vmin, vmax)
#    2146 prune = self._prune
#    2147 if prune == 'lower':
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\ticker.py:2083, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2081 if self._nbins == 'auto':
#    2082     if self.axis is not None:
# -> 2083         nbins = np.clip(self.axis.get_tick_space(),
#    2084                         max(1, self._min_n_ticks - 1), 9)
#    2085     else:
#    2086         nbins = 9
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\axis.py:2734, in YAxis.get_tick_space(self)
#    2733 def get_tick_space(self):
# -> 2734     ends = mtransforms.Bbox.unit().transformed(
#    2735         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2736     length = ends.height * 72
#    2737     # Having a spacing of at least 2 just looks good.
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\transforms.py:479, in BboxBase.transformed(self, transform)
#     475 """
#     476 Construct a `Bbox` by statically transforming this one by *transform*.
#     477 """
#     478 pts = self.get_points()
# --> 479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     481 return Bbox([ll, [lr[0], ul[1]]])
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\transforms.py:2415, in CompositeGenericTransform.transform_affine(self, points)
#    2413 def transform_affine(self, points):
#    2414     # docstring inherited
# -> 2415     return self.get_affine().transform(points)
#
# File D:\AI_Bender\Fast_ai\venv_fast\lib\site-packages\matplotlib\transforms.py:2441, in CompositeGenericTransform.get_affine(self)
#    2439     return self._b.get_affine()
#    2440 else:
# -> 2441     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2442                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Activation Stats

# %%
def show_act_stats(act_stats, n_chart= 10):

    act_stats.plot_stats(figsize= figsize_stats, n_chart= n_chart)
    # act_stats.color_dim(figsize= figsize_cld, n_chart= n_chart)
    # act_stats.color_dim_zoom(figsize= figsize_cldz, n_chart= n_chart)
    act_stats.dead_chart(figsize= figsize_dead, n_chart= n_chart)

# %%
show_act_stats(act_stats, n_chart= 20)

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Saving Model

# %% [raw]
# path_model = Path("models/")
# name_model = "lsun_diffusion_unet_(32_32_64_64_128_128)_(DAAAAA)_InitXavierNormRelu_BN_Bs16_Lr1e-4_10k_40e.pt"
# torch.save(learn.model.state_dict(), path_model/name_model)

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Sampling

# %% [markdown]
# #### DDIM

# %%
sched = DDIMScheduler(beta_end= 0.01)
steps = 100
size = (16, 4, 32, 32)
eta = 1.

samples = sampling(sched, learn.model, steps= steps, size= size, eta= eta)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:03&lt;00:00]
#     </div>

# %%
# %%time

s = samples[-1]/0.18215
with torch.no_grad(): imgs_ddim = latents_to_images(vae, s, clamp= True, device= device)
imgs_ddim.shape
# Out:
# CPU times: total: 13.4 s
# Wall time: 12.7 s
# torch.Size([16, 3, 256, 256])

# %%
show_images_mod(imgs_ddim[:16])

# %%
clean_mem()

# %% [markdown]
# ### ----------------------------------------

# %% [markdown]
# ### Evaluation

# %% [raw]
# dls_eval = DataLoader(dts_tfm, batch_size= bs, shuffle= False)
#
# imgs_eval, _ = next(iter(dls_eval))
# imgs_eval.shape, imgs_eval.dtype

# %% [raw]
# percent_eval = 0.05
#
# samples_eval = SamplesEval(dls_eval, percent= percent_eval, device= device)
# samples_eval.init_kid(feature= 2048, subset_size= 32, reset_real_features= False)

# %% [raw]
# mult = 1e4

# %% [raw]
# #Origin
# kid_ori = samples_eval.kid_eval(imgs_eval)
# kid_ori[0] * mult, kid_ori[1]

# %% [raw]
# #Sample
# kid_samples = samples_eval.kid_eval(imgs_ddim)
# kid_samples[0] * mult, kid_samples[1]

# %% [markdown]
# ### ----------------------------------------
